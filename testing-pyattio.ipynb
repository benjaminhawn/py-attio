# %%
ATTIO_API_KEY = "aa582ed112937dcf0aa0e90862e68b073cc6191e00d13db58d736470b042821c"

# %%
from py_attio.client import Client
attio = Client(ATTIO_API_KEY)

attributes = attio.list_attributes("objects", "858_events")

print(attributes)
# Out:
# {'data': [{'id': {'workspace_id': 'd61206fa-2e75-4ac8-8775-f2418d265af5', 'object_id': '4b2237ee-31cc-4d94-a8c8-aa20dd336f0d', 'attribute_id': '658d5660-dbd6-4197-82bc-5060c1e0defe'}, 'title': 'Record ID', 'description': None, 'api_slug': 'record_id', 'type': 'text', 'is_system_attribute': True, 'is_writable': False, 'is_required': False, 'is_unique': True, 'is_multiselect': False, 'is_default_value_enabled': False, 'is_archived': False, 'default_value': None, 'relationship': None, 'created_at': '2025-04-04T16:53:56.263000000Z', 'config': {'currency': {'default_currency_code': None, 'display_type': None}, 'record_reference': {'allowed_object_ids': None}}}, {'id': {'workspace_id': 'd61206fa-2e75-4ac8-8775-f2418d265af5', 'object_id': '4b2237ee-31cc-4d94-a8c8-aa20dd336f0d', 'attribute_id': '2ddeb115-370b-4126-a5f2-1b425db2686d'}, 'title': 'External ID', 'description': 'Unique external identifier for the 858 Event', 'api_slug': 'external_id', 'type': 'text', 'is_system_attribute': False,
# ...
